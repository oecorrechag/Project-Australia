# %% [markdown]
# # 4.0.0 Export
#
# - En este archivo se crearan los graficos para el dash

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import plotly.express as px
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../") 

import utils.funtionsGraph as fg
from utils.paths2 import direcciones_cursos

G_raw, G_processed, G_interim, G_external, G_models, G_reports, G_reports_figures = direcciones_cursos('australian')

# %%
df = pd.read_parquet(G_processed/'data.parquet.gzip')
df_ts = pd.read_parquet(G_processed/'df_ts.parquet.gzip')
df_cus = pd.read_parquet(G_processed/'df_cus.parquet.gzip')
df_cir = pd.read_parquet(G_processed/'df_cir.parquet.gzip')
df_sto = pd.read_parquet(G_processed/'df_sto.parquet.gzip')

# %%
# Serie de tiempo
df_sto.head()
# Out:
#    stockcode     price  contador
# 23        z8  97543.20      4256
# 4         x5  96714.24      4246
# 10        y3  96689.29      4235
# 13        y6  96338.44      4295
# 6         x7  96125.07      4278

# %%
# unidades diarias
fig = fg.simple_time_series(df_ts, x='date', y="contador", xl='Date', yl='Units')
fig.show()

# %%
# Serie de tiempo
df_ts2 = df_ts.copy()
df_ts2 = df_ts2.loc[:,['date','contador']]
df_ts2['date'] = df_ts2['date'].dt.to_period('M').astype(str)
df_ts2 = df_ts2.groupby('date').sum().reset_index()
print(df_ts2.head(3))

# unidades mensuales
fig = fg.simple_time_series(df_ts2, x='date', y="contador", xl='Date', yl='Units')
fig.show()
# Out:
#       date  contador
# 0  2019-01      4284
# 1  2019-02      3882
# 2  2019-03      4302

# %%
# Serie de tiempo
df_ts2 = df_ts.copy()
df_ts2 = df_ts2.loc[:,['date','contador']]
df_ts2['date'] = df_ts2['date'].dt.to_period('Y').astype(str)
df_ts2 = df_ts2.groupby('date').sum().reset_index()
print(df_ts2.head(3))

# unidades mensuales
fig = fg.simple_time_series(df_ts2, x='date', y="contador", xl='Date', yl='Units')
fig.show()
# Out:
#    date  contador
# 0  2019     50222
# 1  2020     49778

# %%
# customers per day
fig = fg.simple_time_series(df_cus, x='date', y="contador", xl='Date', yl='Customers')
fig.show()

# %%
# Serie de tiempo
df_cus2 = df_cus.copy()
df_cus2['date'] = df_cus2['date'].dt.to_period('M').astype(str)
df_cus2 = df_cus2.drop_duplicates()
df_cus2 = df_cus2.groupby(['date']).sum().reset_index()
print(df_cus2.head(3))

# customers per month
fig = fg.simple_time_series(df_cus2, x='date', y="contador", xl='Date', yl='Customers')
fig.show()
# Out:
#       date  contador
# 0  2019-01      2485
# 1  2019-02      3043
# 2  2019-03      3714

# %%
# Serie de tiempo
df_cus2 = df_cus.copy()
df_cus2['date'] = df_cus2['date'].dt.to_period('Y').astype(str)
df_cus2 = df_cus2.drop_duplicates()
df_cus2 = df_cus2.groupby(['date']).sum().reset_index()
print(df_cus2.head(3))

# customers per year
fig = fg.simple_time_series(df_cus2, x='date', y="contador", xl='Date', yl='Customers')
fig.show()
# Out:
#    date  contador
# 0  2019      8144
# 1  2020      7258

# %%
# Money per day
fig = fg.simple_time_series(df_ts, x='date', y="price", xl='Date', yl='Money')
fig.show()

# %%
# Serie de tiempo
df_ts2 = df_ts.copy()
df_ts2 = df_ts2.loc[:,['date','price']]
df_ts2['date'] = df_ts2['date'].dt.to_period('M').astype(str)
df_ts2 = df_ts2.groupby(['date']).sum().reset_index()
print(df_ts2.head(3))

# customers per day
fig = fg.simple_time_series(df_ts2, x='date', y="price", xl='Date', yl='Money')
fig.show()
# Out:
#       date     price
# 0  2019-01  97108.21
# 1  2019-02  87248.42
# 2  2019-03  97997.74

# %%
# Serie de tiempo
df_ts2 = df_ts.copy()
df_ts2 = df_ts2.loc[:,['date','price']]
df_ts2['date'] = df_ts2['date'].dt.to_period('Y').astype(str)
df_ts2 = df_ts2.groupby(['date']).sum().reset_index()
print(df_ts2.head(3))

# customers per day
fig = fg.simple_time_series(df_ts2, x='date', y="price", xl='Date', yl='Money')
fig.show()
# Out:
#    date       price
# 0  2019  1137152.62
# 1  2020  1124688.77

# %%
fig = fg.simple_bars_plot(df_cir, 'stockcode', 'proporcion', 'Stockcode', 'Proportion')
fig.show()

# %%
df_cir.head()
# Out:
#    stockcode  contador  proporcion
# 13        y6      4295     0.04295
# 6         x7      4278     0.04278
# 23        z8      4256     0.04256
# 4         x5      4246     0.04246
# 10        y3      4235     0.04235

# %%
fig = fg.grafico_circulo(df_cir, 'stockcode', 'Stockcode')
fig.show()

# %%
df_pie = df.copy()
df_pie = df_pie.loc[:,['stockcode_family','stockcode','contador']]
df_pie = df_pie.groupby(['stockcode_family','stockcode']).sum().reset_index()
df_pie = df_pie.sort_values(by=['stockcode_family','stockcode'], ascending=False)
print(df_pie.head(3))
# Out:
#    stockcode_family stockcode  contador
# 23                Z        z8      4256
# 22                Z        z7      4143
# 21                Z        z6      4099

# %%
fig = fg.grafico_circulo2(data = df_pie, x='stockcode', y='stockcode_family', val='contador')
fig.show()

# %%
df_sto.head()
# Out:
#    stockcode     price  contador
# 23        z8  97543.20      4256
# 4         x5  96714.24      4246
# 10        y3  96689.29      4235
# 13        y6  96338.44      4295
# 6         x7  96125.07      4278

# %%
fig = fg.simple_bars_plot(df_sto, 'stockcode', 'price', 'Stockcode', 'Price')
fig.show()
